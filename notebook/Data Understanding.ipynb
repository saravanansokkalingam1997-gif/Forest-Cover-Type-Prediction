# %%
# Retrieve the stored dataset variable
# %store -r forest_cover_df

# %%
# Check the number of rows and columns in the dataset
forest_cover_df.shape
# Out:
# (145890, 55)

# %%
# Display dataset information including data types and non-null counts
forest_cover_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145890 entries, 0 to 145889
# Data columns (total 55 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Elevation                           145890 non-null  int64
#  1   Aspect                              145890 non-null  int64
#  2   Slope                               145890 non-null  int64
#  3   Horizontal_Distance_To_Hydrology    145890 non-null  int64
#  4   Vertical_Distance_To_Hydrology      145890 non-null  int64
#  5   Horizontal_Distance_To_Roadways     145890 non-null  int64
#  6   Hillshade_9am                       145890 non-null  int64
#  7   Hillshade_Noon                      145890 non-null  int64
#  8   Hillshade_3pm                       145890 non-null  int64
#  9   Horizontal_Distance_To_Fire_Points  145890 non-null  int64
#  10  Wilderness_Area_1                   145890 non-null  float64
# ...

# %%
# Generate summary statistics for numerical columns
forest_cover_df.describe()
# Out:
#            Elevation         Aspect          Slope  \
# count  145890.000000  145890.000000  145890.000000
# mean     2874.458949     141.127418      11.925574
# std       210.801279     107.719296       6.319326
# min      1863.000000       0.000000       0.000000
# 25%      2747.000000      54.000000       7.000000
# 50%      2909.000000     108.000000      11.000000
# 75%      3004.000000     217.000000      15.000000
# max      3849.000000     360.000000      61.000000
#
#        Horizontal_Distance_To_Hydrology  Vertical_Distance_To_Hydrology  \
# count                     145890.000000                   145890.000000
# mean                         251.824738                       34.554322
# std                          192.473899                       41.215776
# min                            0.000000                     -146.000000
# 25%                           95.000000                        7.000000
# ...

# %%
# Check the total number of missing values in the dataset
forest_cover_df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# Check the number of duplicate rows in the dataset
forest_cover_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Display the number and unique values for each column
for col in forest_cover_df.columns:

    print(f"{col}:\n Unique values:", forest_cover_df[col].nunique(), "\n", forest_cover_df[col].unique())

    print()
    print()
# Out:
# Elevation:
#  Unique values: 1665
#  [2596 2590 2804 ... 3504 3510 3604]
#
#
# Aspect:
#  Unique values: 361
#  [ 51  56 139 155  45 132  49  59 201 151 134 214 157 259  72   0  38  71
#  209 114  54  22 135 163 148 117 122 105 102  23  41 125  92  98 354 347
#  346 330 128  68  94  99  66 100 323  79  81 315  74  11  42  75 107  90
#   40  63  13  80 166   6  30 118 160 326 153 143 352  14 358 332  18 306
#  173  31 164  34  84 170 211  32  57 348 333 324  88 111  53  58  76  17
#  124 119 320 112  83   1  37 356 307   7  12 344 228 284 299 220   2  95
#  289  21  20 200 349 328 221 257 276 196 189 130 357  15   8 288 129  28
#   86 292 115  29 180 116  46 256 338 127 319  89  43 188  50 138 312   9
#   10  36 167 260 187 279 245  27 359  16  48 149  60  77 230 152  70 325
#  126 222 109  85  25 176 144 175 162  73  39  78 331 329 355  87 285 108
#  106  24  52 261 232 246 342  61 141 216 236 254 336 278  62 237 281  69
# ...

# %%
# Display the frequency of each target class
forest_cover_df['Cover_Type'].value_counts()
# Out:
# Cover_Type
# Lodgepole Pine       103071
# Spruce/Fir            31110
# Aspen                  3069
# Krummholz              2160
# Ponderosa Pine         2160
# Douglas-fir            2160
# Cottonwood/Willow      2160
# Name: count, dtype: int64

# %%
# Display the proportion of each target class
forest_cover_df['Cover_Type'].value_counts(normalize=True)
# Out:
# Cover_Type
# Lodgepole Pine       0.706498
# Spruce/Fir           0.213243
# Aspen                0.021036
# Krummholz            0.014806
# Ponderosa Pine       0.014806
# Douglas-fir          0.014806
# Cottonwood/Willow    0.014806
# Name: proportion, dtype: float64

# %%
# Calculate the ratio between the largest and smallest class frequencies
class_counts = forest_cover_df['Cover_Type'].value_counts()

imbalance_ratio = class_counts.max() / class_counts.min()

imbalance_ratio
# Out:
# 47.71805555555556

# %%
import matplotlib.pyplot as plt

# Plot the distribution of target classes
forest_cover_df['Cover_Type'].value_counts().plot(kind='bar')

# Add title and axis labels
plt.title("Class Distribution")
plt.xlabel("Cover Type")
plt.ylabel("Count")

# Display the plot
plt.show()
